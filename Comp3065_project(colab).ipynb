# %%
# !git clone https://github.com/hiiammikezzz/DerainCycleGAN.git
# Out:
# Cloning into 'DerainCycleGAN'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 138 (delta 8), reused 0 (delta 0), pack-reused 115
# Receiving objects: 100% (138/138), 1.51 MiB | 23.08 MiB/s, done.
# Resolving deltas: 100% (60/60), done.

# %%
# !pip install scikit-image

# %%
# !pip install tensorboardX
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 1.9 MB/s eta 0:00:00
# ...

# %%
# !pip install torchfile
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5693 sha256=53616d70a2e3d4cbb9379eedc71de6d6cd05f05d0422d200b4e53ce6e0a53bd1
#   Stored in directory: /root/.cache/pip/wheels/c7/e9/87/1c51daf8e468d5c14931f8ac3344880f903ba96b063675cac2
# Successfully built torchfile
# ...

# %%
#this link is expired
#!wget http://cs.stanford.edu/people/jcjohns/fast-neural-style/models/vgg16.t7 -O

# %%
#put the pretrained vgg16 model into the vgg16 flie
# !wget -O vgg16.pth https://download.pytorch.org/models/vgg16-397923af.pth
# Out:
# --2024-04-14 08:51:20--  https://download.pytorch.org/models/vgg16-397923af.pth
# Resolving download.pytorch.org (download.pytorch.org)... 99.86.38.37, 99.86.38.72, 99.86.38.96, ...
# Connecting to download.pytorch.org (download.pytorch.org)|99.86.38.37|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 553433881 (528M) [binary/octet-stream]
# Saving to: ‘vgg16.pth’
#
# vgg16.pth           100%[===================>] 527.79M   239MB/s    in 2.2s
#
# 2024-04-14 08:51:22 (239 MB/s) - ‘vgg16.pth’ saved [553433881/553433881]

# %%
# !mv /content/vgg16.pth /content/DerainCycleGAN/vgg16

# %%
# !pip install gdown

# %%
#download the dataset (Rain100H) 25s%
# !gdown --id '1SH9Gn8cg4_qjFYp-KTdzbYlukI9bVnBG'
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:138: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1SH9Gn8cg4_qjFYp-KTdzbYlukI9bVnBG
# From (redirected): https://drive.google.com/uc?id=1SH9Gn8cg4_qjFYp-KTdzbYlukI9bVnBG&confirm=t&uuid=e3713ca1-9cc5-407d-afc9-14b200337016
# To: /content/rain_data_Rain100H.zip
# 100% 416M/416M [00:04<00:00, 102MB/s]

# %%
# !unzip /content/rain_data_Rain100H.zip
# Out:
# Archive:  /content/rain_data_Rain100H.zip
#    creating: rain_data_Rain100H/rain_data_test_Rain100H_100/
#    creating: rain_data_Rain100H/rain_data_test_Rain100H_100/trainA/
#   inflating: rain_data_Rain100H/rain_data_test_Rain100H_100/trainA/rain-1.png
#   inflating: rain_data_Rain100H/rain_data_test_Rain100H_100/trainA/rain-10.png
#   inflating: rain_data_Rain100H/rain_data_test_Rain100H_100/trainA/rain-100.png
#   inflating: rain_data_Rain100H/rain_data_test_Rain100H_100/trainA/rain-101.png
#   inflating: rain_data_Rain100H/rain_data_test_Rain100H_100/trainA/rain-102.png
#   inflating: rain_data_Rain100H/rain_data_test_Rain100H_100/trainA/rain-103.png
#   inflating: rain_data_Rain100H/rain_data_test_Rain100H_100/trainA/rain-104.png
#   inflating: rain_data_Rain100H/rain_data_test_Rain100H_100/trainA/rain-105.png
#   inflating: rain_data_Rain100H/rain_data_test_Rain100H_100/trainA/rain-106.png
#   inflating: rain_data_Rain100H/rain_data_test_Rain100H_100/trainA/rain-107.png
# ...

# %%
#create
# !mv /content/rain_data_Rain100H/rain_data_train_Rain100H/trainA /content/DerainCycleGAN/datasets/rainy_Rain100H
# !mv /content/rain_data_Rain100H/rain_data_train_Rain100H/trainB /content/DerainCycleGAN/datasets/rainy_Rain100H
# !mv /content/rain_data_Rain100H/rain_data_test_Rain100H_100/trainA /content/DerainCycleGAN/datasets/test_rain100H
# !mv /content/rain_data_Rain100H/rain_data_test_Rain100H_100/trainB /content/DerainCycleGAN/datasets/test_rain100H

# %%
# !CUDA_VISIBLE_DEVICES=0,1,2,3 python3 ./DerainCycleGAN/src/train.py --n_ep 100 --train_path ./DerainCycleGAN/datasets/rainy_Rain100H --val_path ./DerainCycleGAN/datasets/test_rain100H --display_dir ./DerainCycleGAN/logs --result_dir ./DerainCycleGAN/results --name Rain100H
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# total_it: 30070 (ep 66, it 370), lr 0.000100, disA 0.259071, disB 0.244596, ganA 0.268156, ganB 0.215442, recA 0.363880, recB 0.322167, percp 0.000000, cons_loss 0.047621, attB 0.018376, total 1.235641
# total_it: 30080 (ep 66, it 380), lr 0.000100, disA 0.196051, disB 0.231369, ganA 0.473677, ganB 0.531478, recA 0.351082, recB 0.327964, percp 0.000000, cons_loss 0.041753, attB 0.063242, total 1.789196
# total_it: 30090 (ep 66, it 390), lr 0.000100, disA 0.164572, disB 0.163121, ganA 0.352626, ganB 0.309620, recA 0.392763, recB 0.315393, percp 0.000000, cons_loss 0.060879, attB 0.012983, total 1.444264
# total_it: 30100 (ep 66, it 400), lr 0.000100, disA 0.127433, disB 0.051734, ganA 0.348779, ganB 0.296526, recA 0.291042, recB 0.188461, percp 0.000000, cons_loss 0.027296, attB 0.011775, total 1.163879
# ...

# %%
#!CUDA_VISIBLE_DEVICES=0,1,2,3 python3 ./DerainCycleGAN/src/test.py --test_path ./DerainCycleGAN/datasets --name Rain100H --resume ./DerainCycleGAN/results/Rain100L/net_best_Rain100H.pth --mode 0
# !CUDA_VISIBLE_DEVICES=0,1,2,3 python3 ./DerainCycleGAN/src/test.py --test_path ./DerainCycleGAN/datasets --name Rain100H --resume ./DerainCycleGAN/results/Rain100H/net_best_00088.pth --result_dir ./DerainCycleGAN/outputs/ --mode 0
# Out:
# --- load options ---
# a2b: 1
# auto_path: ../datasets
# crop_size: 216
# gan_mode: lsgan
# gpu: 0
# input_dim_a: 3
# input_dim_b: 3
# mode: 0
# nThreads: 4
# name: Rain100H
# num: 5
# phase: test
# pool_size: 50
# resize_size: 256
# result_dir: ./DerainCycleGAN/outputs/
# resume: ./DerainCycleGAN/results/Rain100H/net_best_00088.pth
# test_path: ./DerainCycleGAN/datasets
#
# --- load dataset ---
# _rain100H: 100 images
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#
# --- load model ---
#
# --- testing ---
# ...

# %%
# !zip -r logs.zip /content/DerainCycleGAN/logs
# !zip -r outputs.zip /content/DerainCycleGAN/outputs
# !zip -r results.zip /content/DerainCycleGAN/results
# Out:
#   adding: content/DerainCycleGAN/logs/ (stored 0%)
#   adding: content/DerainCycleGAN/logs/README.md (stored 0%)
#   adding: content/DerainCycleGAN/logs/Rain100H/ (stored 0%)
#   adding: content/DerainCycleGAN/logs/Rain100H/events.out.tfevents.1713084709.5575d1acda18 (deflated 0%)
#   adding: content/DerainCycleGAN/logs/Rain100H/events.out.tfevents.1713084778.5575d1acda18
#
#
# zip error: Interrupted (aborting)
#   adding: content/DerainCycleGAN/outputs/ (stored 0%)
#   adding: content/DerainCycleGAN/outputs/README.md (stored 0%)
#   adding: content/DerainCycleGAN/outputs/Rain100H/ (stored 0%)
#   adding: content/DerainCycleGAN/outputs/Rain100H/20.png (deflated 0%)
#   adding: content/DerainCycleGAN/outputs/Rain100H/15.png (deflated 0%)
#   adding: content/DerainCycleGAN/outputs/Rain100H/32.png (deflated 0%)
#   adding: content/DerainCycleGAN/outputs/Rain100H/5.png (deflated 0%)
#   adding: content/DerainCycleGAN/outputs/Rain100H/33.png (deflated 0%)
# ...

# %%
# !zip -r logs.zip /content/DerainCycleGAN/logs
# Out:
#   adding: content/DerainCycleGAN/logs/ (stored 0%)
#   adding: content/DerainCycleGAN/logs/README.md (stored 0%)
#   adding: content/DerainCycleGAN/logs/Rain100H/ (stored 0%)
#   adding: content/DerainCycleGAN/logs/Rain100H/events.out.tfevents.1713084709.5575d1acda18 (deflated 0%)
#   adding: content/DerainCycleGAN/logs/Rain100H/events.out.tfevents.1713084778.5575d1acda18 (deflated 0%)

# %%
from google.colab import files
files.download('/content/results.zip')
files.download('/content/outputs.zip')
files.download('/content/logs.zip')
